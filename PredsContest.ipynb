# %%
import mechanicalsoup as ms

url = r'https://nashvillepredators.formstack.com/forms/untitled_form_139'

# %%
browser = ms.StatefulBrowser()
browser.open(url)
browser.select_form()

# %%
browser['field40856577-first'] = "Samuel"
browser['field40856577-last'] = "Dotson"
browser["field40856578"] = "samdotson1992@gmail.com"
browser["field40856578_confirm"] = "samdotson1992@gmail.com"
browser["field40856583-address"] = "3728 Clairmont Rd."
browser["field40856583-city"] = "Chamblee"
browser["field40856583-state"] = "GA"
browser["field40856587"] = "Yannick Weber"
browser["field40857186"] = "Yes"

# %%
browser.get_current_form().print_summary()
# Out:
# <input name="form" type="hidden" value="2311073"/>
# <input name="viewkey" type="hidden" value="J3ih5CPdIn"/>
# <input name="password" type="hidden" value=""/>
# <input id="hidden_fields2311073" name="hidden_fields" type="hidden" value=""/>
# <input id="incomplete2311073" name="incomplete" type="hidden" value=""/>
# <input id="incomplete_email2311073" name="incomplete_email" type="hidden" value=""/>
# <input id="incomplete_password2311073" name="incomplete_password" type="hidden"/>
# <input id="referrer2311073" name="referrer" type="hidden" value=""/>
# <input id="referrer_type2311073" name="referrer_type" type="hidden" value="link"/>
# <input name="_submit" type="hidden" value="1"/>
# <input name="style_version" type="hidden" value="3"/>
# <input id="fsLatitude" name="latitude" type="hidden" value=""/>
# <input id="fsLongitude" name="longitude" type="hidden" value=""/>
# <input id="viewparam" name="viewparam" type="hidden" value="17363"/>
# ...

# %%
response = browser.submit_selected()

# %%
response
# Out:
# <Response [200]>

# %%
browser.get_current_page()
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# ...

# %%
browser.get_url()
# Out:
# 'https://nashvillepredators.formstack.com/forms/index.php'
